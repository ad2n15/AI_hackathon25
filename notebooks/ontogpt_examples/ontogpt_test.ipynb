# %%
# %env PATH=../.local/bin:$PATH
# Out:
# env: PATH=../.local/bin:$PATH

# %%
# !ontogpt complete --help
# Out:
# Usage: ontogpt complete [OPTIONS] [INPUT]
#
#   Prompt completion.
#
#   The input argument may be:     A file path,     or a string. Use the
#   -i/--input-file option followed by the path to the input file. Otherwise,
#   the input is assumed to be a string to be read as input.
#
# Options:
#   -i, --inputfile TEXT            Path to a file containing input text.
#   -m, --model TEXT                Model name to use, e.g. orca-mini-7b or
#                                   gpt-4. See all model names with ontogpt
#                                   list-models.
#   -o, --output FILENAME           Output file.
#   -O, --output-format [json|yaml|pickle|md|html|owl|turtle|jsonl|kgx|csv|tsv]
#                                   Output format.
#   --show-prompt / --no-show-prompt
#                                   If set, show all prompts passed to model
#                                   through an API. Use with verbose setting.
#                                   [default: no-show-prompt]
#   --api-base TEXT                 Base to use for LLM API, e.g. for the Azure
#                                   OpenAI API. Note this may also be set
#                                   through the runoak set-apikey command.
#   --api-version TEXT              Version to use for LLM API, e.g. for the
#                                   Azure OpenAI API. Note this may also be set
#                                   through the runoak set-apikey command.
#   --model-provider TEXT           Specify a provider if model is not specified
#                                   in the model name. If using a proxy using
#                                   the OpenAI API format, this should be set to
#                                   'openai'.
#   --system-message TEXT           System message to provide to the LLM, e.g.,
#                                   'You will extract knowledge from this text.'
#   -p, --temperature FLOAT         Temperature for model completion.
#   --cut-input-text / --no-cut-input-text
#                                   If set, outputs will contain only the first
#                                   1000 characters of each input text. This is
#                                   useful when processing many documents.
#                                   [default: no-cut-input-text]
#   --api-base TEXT                 Base to use for LLM API, e.g. for the Azure
#                                   OpenAI API. Note this may also be set
#                                   through the runoak set-apikey command.
#   --api-version TEXT              Version to use for LLM API, e.g. for the
#                                   Azure OpenAI API. Note this may also be set
#                                   through the runoak set-apikey command.
#   --model-provider TEXT           Specify a provider if model is not specified
#                                   in the model name. If using a proxy using
#                                   the OpenAI API format, this should be set to
#                                   'openai'.
#   --system-message TEXT           System message to provide to the LLM, e.g.,
#                                   'You will extract knowledge from this text.'
#   --help                          Show this message and exit.

# %%
# !ontogpt complete -m ollama/gemma:7b  "Why did the squid cross the coral reef?"
# Out:
# To get to the other tentacles!

# %%
# Out:
# ERROR:root:Line '- cGAS' does not contain a colon; ignoring
# ERROR:root:Line '- STING' does not contain a colon; ignoring
# ERROR:root:Line '- US3' does not contain a colon; ignoring
# ERROR:root:Cannot find slot for gene-organism in Gene-organisms:;- β-catenin / HSV-1
# ERROR:root:Line '- US3 / HSV-1' does not contain a colon; ignoring
# ERROR:root:Cannot find slot for gene-gene_interaction in Gene-gene_interactions:;- Not mentioned in the provided text.
# ERROR:root:Line 'The provided text does not include any information about genes or locations, so I am unable to extract the requested data from the given context.' does not contain a colon; ignoring
# Traceback (most recent call last):
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connection.py", line 174, in _new_conn
#     conn = connection.create_connection(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/util/connection.py", line 95, in create_connection
#     raise err
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/util/connection.py", line 85, in create_connection
#     sock.connect(sa)
# OSError: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/httpsession.py", line 464, in send
#     urllib_response = conn.urlopen(
#                       ^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connectionpool.py", line 802, in urlopen
#     retries = retries.increment(
#               ^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/util/retry.py", line 527, in increment
#     raise six.reraise(type(error), error, _stacktrace)
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/packages/six.py", line 770, in reraise
#     raise value
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connectionpool.py", line 716, in urlopen
#     httplib_response = self._make_request(
#                        ^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connectionpool.py", line 404, in _make_request
#     self._validate_conn(conn)
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connectionpool.py", line 1061, in _validate_conn
#     conn.connect()
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connection.py", line 363, in connect
#     self.sock = conn = self._new_conn()
#                        ^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/urllib3/connection.py", line 186, in _new_conn
#     raise NewConnectionError(
# urllib3.exceptions.NewConnectionError: <botocore.awsrequest.AWSHTTPSConnection object at 0x7fcbd42735d0>: Failed to establish a new connection: [Errno 101] Network is unreachable
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/notebooks/../.local/bin/ontogpt", line 8, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/click/core.py", line 1161, in __call__
#     return self.main(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/click/core.py", line 1082, in main
#     rv = self.invoke(ctx)
#          ^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/click/core.py", line 1697, in invoke
#     return _process_result(sub_ctx.command.invoke(sub_ctx))
#                            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/click/core.py", line 1443, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.11/site-packages/click/core.py", line 788, in invoke
#     return __callback(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/ontogpt/cli.py", line 518, in extract
#     results = ke.extract_from_text(
#               ^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/ontogpt/engines/spires_engine.py", line 122, in extract_from_text
#     extracted_object = self.parse_completion_payload(
#                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/ontogpt/engines/spires_engine.py", line 686, in parse_completion_payload
#     return self.ground_annotation_object(raw, cls)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/ontogpt/engines/spires_engine.py", line 758, in ground_annotation_object
#     obj = self.normalize_named_entity(val, slot.range)  # type: ignore
#           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/ontogpt/engines/knowledge_engine.py", line 395, in normalize_named_entity
#     for obj_id in self.groundings(text, cls):
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/ontogpt/engines/knowledge_engine.py", line 600, in groundings
#     self.annotators[annotator] = get_adapter(annotator)
#                                  ^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/oaklib/selector.py", line 155, in get_adapter
#     return res.implementation_class(res, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<string>", line 17, in __init__
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/oaklib/implementations/gilda.py", line 52, in __post_init__
#     self.grounder = Grounder(terms=self.resource.slug)
#                     ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/gilda/grounder.py", line 85, in __init__
#     terms = get_grounding_terms()
#             ^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/gilda/resources/__init__.py", line 77, in get_grounding_terms
#     out_file = _download_from_s3(resource_dir, base_name)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/gilda/resources/__init__.py", line 68, in _download_from_s3
#     s3.download_file('gilda', full_key, out_file, Config=tc)
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/boto3/s3/inject.py", line 223, in download_file
#     return transfer.download_file(
#            ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/boto3/s3/transfer.py", line 406, in download_file
#     future.result()
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/s3transfer/futures.py", line 111, in result
#     return self._coordinator.result()
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/s3transfer/futures.py", line 272, in result
#     raise self._exception
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/s3transfer/tasks.py", line 272, in _main
#     self._submit(transfer_future=transfer_future, **kwargs)
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/s3transfer/download.py", line 352, in _submit
#     response = client.head_object(
#                ^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/client.py", line 570, in _api_call
#     return self._make_api_call(operation_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/context.py", line 124, in wrapper
#     return func(*args, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/client.py", line 1013, in _make_api_call
#     http, parsed_response = self._make_request(
#                             ^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/client.py", line 1037, in _make_request
#     return self._endpoint.make_request(operation_model, request_dict)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/endpoint.py", line 119, in make_request
#     return self._send_request(request_dict, operation_model)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/endpoint.py", line 200, in _send_request
#     while self._needs_retry(
#           ^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/endpoint.py", line 360, in _needs_retry
#     responses = self._event_emitter.emit(
#                 ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/hooks.py", line 412, in emit
#     return self._emitter.emit(aliased_event_name, **kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/hooks.py", line 256, in emit
#     return self._emit(event_name, kwargs)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/hooks.py", line 239, in _emit
#     response = handler(**kwargs)
#                ^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/retryhandler.py", line 207, in __call__
#     if self._checker(**checker_kwargs):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/retryhandler.py", line 284, in __call__
#     should_retry = self._should_retry(
#                    ^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/retryhandler.py", line 320, in _should_retry
#     return self._checker(attempt_number, response, caught_exception)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/retryhandler.py", line 363, in __call__
#     checker_response = checker(
#                        ^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/retryhandler.py", line 247, in __call__
#     return self._check_caught_exception(
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/retryhandler.py", line 416, in _check_caught_exception
#     raise caught_exception
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/endpoint.py", line 279, in _do_get_response
#     http_response = self._send(request)
#                     ^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/endpoint.py", line 383, in _send
#     return self.http_session.send(request)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/scratch/aazd1f17/shared_space/AI_hackathon25/.local/lib/python3.11/site-packages/botocore/httpsession.py", line 493, in send
#     raise EndpointConnectionError(endpoint_url=request.url, error=e)
# botocore.exceptions.EndpointConnectionError: Could not connect to the endpoint URL: "https://gilda.s3.amazonaws.com/1.4.0/grounding_terms.tsv.gz"
