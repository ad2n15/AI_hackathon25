# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import classification_report,confusion_matrix,ConfusionMatrixDisplay
import warnings
import seaborn as sns
import matplotlib.pyplot as plt
import umap
import pandas as pd
import numpy as np
import logging
import torch
from helical.utils import get_anndata_from_hf_dataset
from datasets import load_dataset

logging.getLogger().setLevel(logging.ERROR)

warnings.filterwarnings("ignore")

# Import Geneformer & UCE from the Helical package
from helical.models.geneformer import Geneformer,GeneformerConfig
from helical.models.uce import UCE, UCEConfig
# Out:
# INFO:datasets:PyTorch version 2.6.0 available.

# %%
import anndata as ad

ann_data = ad.read_h5ad("../fb338c4d-e63a-4b17-abd6-1032a66c8886.h5ad")

# %%
ann_data
# Out:
# AnnData object with n_obs × n_vars = 422220 × 33105
#     obs: 'Ethnicity', 'BMI', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'Age_group', 'COVID_severity', 'COVID_status', 'Group', 'Smoker', 'sample_id', 'sequencing_library', 'Protein_modality_weight', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'donor_id', 'suspension_type', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'name', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'antibody_X', 'antibody_features', 'citation', 'default_embedding', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_umap_after_harmony_ADT', 'X_umap_after_harmony_RNA', 'X_umap_before_harmony_ADT', 'X_umap_before_harmony_RNA', 'X_umap_wnn_derived'

# %%
# Shuffle the dataset.
# Seed used for reproducibility
#hf_dataset.shuffle(seed=42)
#X_train = get_anndata_from_hf_dataset(hf_dataset["train"])[:1000]
#X_test = get_anndata_from_hf_dataset(hf_dataset["test"])[:100]

import anndata as ad
from sklearn.model_selection import train_test_split


ann_data.X = ann_data.raw.X.copy()
# Shuffle the AnnData object by its observations (cells)
ann_data = ann_data[ann_data.obs.sample(frac=1, random_state=42).index]

# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test = train_test_split(ann_data, test_size=0.2, random_state=42)

# Now you have train_adata and test_adata while keeping the AnnData structure intact
X_train
# Out:
# View of AnnData object with n_obs × n_vars = 337776 × 33105
#     obs: 'Ethnicity', 'BMI', 'annotation_broad', 'annotation_detailed', 'annotation_detailed_fullNames', 'Age_group', 'COVID_severity', 'COVID_status', 'Group', 'Smoker', 'sample_id', 'sequencing_library', 'Protein_modality_weight', 'assay_ontology_term_id', 'cell_type_ontology_term_id', 'development_stage_ontology_term_id', 'disease_ontology_term_id', 'is_primary_data', 'organism_ontology_term_id', 'sex_ontology_term_id', 'tissue_ontology_term_id', 'self_reported_ethnicity_ontology_term_id', 'donor_id', 'suspension_type', 'tissue_type', 'cell_type', 'assay', 'disease', 'organism', 'sex', 'tissue', 'self_reported_ethnicity', 'development_stage', 'observation_joinid'
#     var: 'name', 'feature_is_filtered', 'feature_name', 'feature_reference', 'feature_biotype', 'feature_length', 'feature_type'
#     uns: 'antibody_X', 'antibody_features', 'citation', 'default_embedding', 'schema_reference', 'schema_version', 'title'
#     obsm: 'X_umap_after_harmony_ADT', 'X_umap_after_harmony_RNA', 'X_umap_before_harmony_ADT', 'X_umap_before_harmony_RNA', 'X_umap_wnn_derived'

# %%
device = "cuda" if torch.cuda.is_available() else "cpu"
model_config = GeneformerConfig(batch_size=10,device=device)   
geneformer = Geneformer(configurer=model_config)

# %%
#print(ann_data.var.index)
#?geneformer.get_embeddings
# %ls /bin/
# Out:
#  X11@                              lzcat@
# '['*                               lzcmp@
#  aclocal@                          lzdiff@
#  aclocal-1.16*                     lzegrep@
#  addpart*                          lzfgrep@
#  addr2line@                        lzgrep@
#  animate@                          lzless@
#  animate-im6@                      lzma@
#  animate-im6.q16*                  lzmainfo*
#  apt*                              lzmore@
#  apt-cache*                        m4*
#  apt-cdrom*                        make*
#  apt-config*                       make-first-existing-target*
#  apt-get*                          makeconv*
#  apt-key*                          mariadb-config@
#  apt-mark*                         mariadb_config*
#  ar@                               mawk*
#  arch*                             mcookie*
#  as@                               md5sum*
#  autoconf*                         md5sum.textutils@
#  autoheader*                       mesg*
#  autom4te*                         migrate-pubring-from-classic-gpg*
#  automake@                         mkdir*
#  automake-1.16*                    mkfifo*
#  autoreconf*                       mknod*
#  autoscan*                         mktemp*
#  autoupdate*                       mogrify@
#  awk@                              mogrify-im6@
#  b2sum*                            mogrify-im6.q16*
#  base32*                           montage@
#  base64*                           montage-im6@
#  basename*                         montage-im6.q16*
#  basenc*                           more*
#  bash*                             mount*
#  bashbug*                          mountpoint*
#  bunzip2*                          mv*
#  bzcat*                            mysql_config@
#  bzcmp@                            namei*
#  bzdiff*                           nawk@
#  bzegrep@                          ncurses5-config@
#  bzexe*                            ncurses6-config*
#  bzfgrep@                          ncursesw5-config@
#  bzgrep*                           ncursesw6-config*
#  bzip2*                            newgrp*
#  bzip2recover*                     nice*
#  bzless@                           nisdomainname@
#  bzmore*                           nl*
#  c++@                              nm@
#  c++filt@                          nohup*
#  c89@                              nproc*
#  c89-gcc*                          nsenter*
#  c99@                              numfmt*
#  c99-gcc*                          objcopy@
#  c_rehash*                         objdump@
#  captoinfo@                        od*
#  cat*                              openssl*
#  cc@                               pager@
#  chage*                            partx*
#  chattr*                           passwd*
#  chcon*                            paste*
#  chfn*                             patch*
#  chg*                              pathchk*
#  chgrp*                            pcre2-config*
#  chmod*                            pdb3@
#  choom*                            pdb3.11@
#  chown*                            perl*
#  chrt*                             perl5.36-x86_64-linux-gnu*
#  chsh*                             perl5.36.0*
#  cksum*                            perlbug*
#  clear*                            perldoc*
#  clear_console*                    perlivp*
#  cmake*                            perlthanks*
#  cmp*                              pg_config*
#  comm*                             pgrep*
#  compare@                          piconv*
#  compare-im6@                      pidof@
#  compare-im6.q16*                  pidwait*
#  compile_et*                       pinentry@
#  composite@                        pinentry-curses*
#  composite-im6@                    pinky*
#  composite-im6.q16*                pkg-config@
#  conjure@                          pkgconf*
#  conjure-im6@                      pkgdata*
#  conjure-im6.q16*                  pkill@
#  convert@                          pl2pm*
#  convert-im6@                      pldd*
#  convert-im6.q16*                  pmap*
#  corelist*                         pod2html*
#  cp*                               pod2man*
#  cpack*                            pod2text*
#  cpan*                             pod2usage*
#  cpan5.36-x86_64-linux-gnu*        podchecker*
#  cpp@                              pr*
#  cpp-12@                           printenv*
#  csplit*                           printf*
#  ctest*                            prlimit*
#  curl*                             prove*
#  curl-config*                      ps*
#  cut*                              ptar*
#  dash*                             ptardiff*
#  date*                             ptargrep*
#  dd*                               ptx*
#  deb-systemd-helper*               pwd*
#  deb-systemd-invoke*               pwdx*
#  debconf*                          py3clean*
#  debconf-apt-progress*             py3compile*
#  debconf-communicate*              py3versions@
#  debconf-copydb*                   pydoc3@
#  debconf-escape*                   pydoc3.11*
#  debconf-set-selections*           pygettext3@
#  debconf-show*                     pygettext3.11*
#  delpart*                          python3@
#  derb*                             python3.11*
#  df*                               ranlib@
#  dh_autotools-dev_restoreconfig*   rbash@
#  dh_autotools-dev_updateconfig*    readelf@
#  diff*                             readlink*
#  diff3*                            realpath*
#  dir*                              rename.ul*
#  dircolors*                        renice*
#  dirmngr*                          reset@
#  dirmngr-client*                   resizepart*
#  dirname*                          rev*
#  display@                          rgrep*
#  display-im6@                      rm*
#  display-im6.q16*                  rmdir*
#  dmesg*                            rpcgen*
#  dnsdomainname@                    run-parts*
#  domainname@                       runcon*
#  dpkg*                             savelog*
#  dpkg-architecture*                scalar*
#  dpkg-buildflags*                  scp*
#  dpkg-buildpackage*                script*
#  dpkg-checkbuilddeps*              scriptlive*
#  dpkg-deb*                         scriptreplay*
#  dpkg-distaddfile*                 sdiff*
#  dpkg-divert*                      sed*
#  dpkg-genbuildinfo*                select-editor*
#  dpkg-genchanges*                  sensible-browser*
#  dpkg-gencontrol*                  sensible-editor*
#  dpkg-gensymbols*                  sensible-pager*
#  dpkg-maintscript-helper*          seq*
#  dpkg-mergechangelogs*             setarch*
#  dpkg-name*                        setpriv*
#  dpkg-parsechangelog*              setsid*
#  dpkg-query*                       setterm*
#  dpkg-realpath*                    sftp*
#  dpkg-scanpackages*                sg@
#  dpkg-scansources*                 sh@
#  dpkg-shlibdeps*                   sha1sum*
#  dpkg-source*                      sha224sum*
#  dpkg-split*                       sha256sum*
#  dpkg-statoverride*                sha384sum*
#  dpkg-trigger*                     sha512sum*
#  dpkg-vendor*                      shasum*
#  du*                               shred*
#  dwp@                              shuf*
#  echo*                             size@
#  egrep*                            skill*
#  elfedit@                          slabtop*
#  enc2xs*                           sleep*
#  encguess*                         slogin@
#  env*                              snice@
#  expand*                           sort*
#  expiry*                           splain*
#  expr*                             split*
#  f77@                              sq*
#  f95@                              ssh*
#  factor*                           ssh-add*
#  faillog*                          ssh-agent*
#  fallocate*                        ssh-argv0*
#  false*                            ssh-copy-id*
#  fc-cache*                         ssh-keygen*
#  fc-cat*                           ssh-keyscan*
#  fc-conflist*                      stat*
#  fc-list*                          stdbuf*
#  fc-match*                         stream@
#  fc-pattern*                       stream-im6@
#  fc-query*                         stream-im6.q16*
#  fc-scan*                          streamzip*
#  fc-validate*                      strings@
#  fgrep*                            strip@
#  file*                             stty*
#  fincore*                          su*
#  find*                             sum*
#  findmnt*                          svn*
#  flock*                            svnadmin*
#  fmt*                              svnauthz*
#  fold*                             svnauthz-validate*
#  free*                             svnbench*
#  funzip*                           svndumpfilter*
#  g++@                              svnfsfs*
#  g++-12@                           svnlook*
#  gapplication*                     svnmucc*
#  gcc@                              svnrdump*
#  gcc-12@                           svnserve*
#  gcc-ar@                           svnsync*
#  gcc-ar-12@                        svnversion*
#  gcc-nm@                           sync*
#  gcc-nm-12@                        tabs*
#  gcc-ranlib@                       tac*
#  gcc-ranlib-12@                    tail*
#  gcov@                             tar*
#  gcov-12@                          taskset*
#  gcov-dump@                        tclsh@
#  gcov-dump-12@                     tclsh8.6*
#  gcov-tool@                        tcltk-depends*
#  gcov-tool-12@                     tee*
#  gdbus*                            tempfile*
#  gdbus-codegen*                    test*
#  gdk-pixbuf-csource*               tic*
#  gdk-pixbuf-pixdata*               timeout*
#  gdk-pixbuf-thumbnailer*           tload*
#  genbrk*                           toe*
#  gencat*                           top*
#  gencfu*                           touch*
#  gencnval*                         tput*
#  gendict*                          tr*
#  genrb*                            true*
#  getconf*                          truncate*
#  getent*                           tset*
#  getopt*                           tsort*
#  gfortran@                         tty*
#  gfortran-12@                      tzselect*
#  gio*                              ucf*
#  gio-querymodules@                 ucfq*
#  git*                              ucfr*
#  git-receive-pack@                 uclampset*
#  git-shell*                        uconv*
#  git-upload-archive@               umount*
#  git-upload-pack@                  uname*
#  glib-compile-resources*           uncompress*
#  glib-compile-schemas@             unexpand*
#  glib-genmarshal*                  uniq*
#  glib-gettextize*                  unlink*
#  glib-mkenums*                     unlzma@
#  gmake@                            unshare*
#  gobject-query*                    unxz@
#  gold@                             unzip*
#  gp-archive@                       unzipsfx*
#  gp-collect-app@                   update-alternatives*
#  gp-display-html@                  update-mime-database*
#  gp-display-src@                   uptime*
#  gp-display-text@                  users*
#  gpasswd*                          utmpdump*
#  gpg*                              vdir*
#  gpg-agent*                        vmstat*
#  gpg-connect-agent*                w*
#  gpg-wks-server*                   wall*
#  gpg-zip*                          watch*
#  gpgcompose*                       watchgnupg*
#  gpgconf*                          wc*
#  gpgparsemail*                     wdctl*
#  gpgsm*                            wget*
#  gpgsplit*                         whereis*
#  gpgtar*                           which@
#  gpgv*                             which.debianutils*
#  gprof@                            who*
#  gprofng@                          whoami*
#  grep*                             wish@
#  gresource*                        wish8.6*
#  groups*                           x86_64@
#  gsettings*                        x86_64-linux-gnu-addr2line*
#  gtester*                          x86_64-linux-gnu-ar*
#  gtester-report*                   x86_64-linux-gnu-as*
#  gunzip*                           x86_64-linux-gnu-c++filt*
#  gzexe*                            x86_64-linux-gnu-cpp@
#  gzip*                             x86_64-linux-gnu-cpp-12*
#  h2ph*                             x86_64-linux-gnu-dwp*
#  h2xs*                             x86_64-linux-gnu-elfedit*
#  hardlink*                         x86_64-linux-gnu-g++@
#  head*                             x86_64-linux-gnu-g++-12*
#  hg*                               x86_64-linux-gnu-gcc@
#  hg-ssh*                           x86_64-linux-gnu-gcc-12*
#  hostid*                           x86_64-linux-gnu-gcc-ar@
#  hostname*                         x86_64-linux-gnu-gcc-ar-12*
#  i386@                             x86_64-linux-gnu-gcc-nm@
#  iconv*                            x86_64-linux-gnu-gcc-nm-12*
#  icuexportdata*                    x86_64-linux-gnu-gcc-ranlib@
#  icuinfo*                          x86_64-linux-gnu-gcc-ranlib-12*
#  id*                               x86_64-linux-gnu-gcov@
#  identify@                         x86_64-linux-gnu-gcov-12*
#  identify-im6@                     x86_64-linux-gnu-gcov-dump@
#  identify-im6.q16*                 x86_64-linux-gnu-gcov-dump-12*
#  ifnames*                          x86_64-linux-gnu-gcov-tool@
#  import@                           x86_64-linux-gnu-gcov-tool-12*
#  import-im6@                       x86_64-linux-gnu-gfortran@
#  import-im6.q16*                   x86_64-linux-gnu-gfortran-12*
#  infocmp*                          x86_64-linux-gnu-gold@
#  infotocap@                        x86_64-linux-gnu-gp-archive*
#  install*                          x86_64-linux-gnu-gp-collect-app*
#  instmodsh*                        x86_64-linux-gnu-gp-display-html*
#  ionice*                           x86_64-linux-gnu-gp-display-src*
#  ipcmk*                            x86_64-linux-gnu-gp-display-text*
#  ipcrm*                            x86_64-linux-gnu-gprof*
#  ipcs*                             x86_64-linux-gnu-gprofng*
#  ischroot*                         x86_64-linux-gnu-ld@
#  join*                             x86_64-linux-gnu-ld.bfd*
#  json_pp*                          x86_64-linux-gnu-ld.gold*
#  kbxutil*                          x86_64-linux-gnu-lto-dump@
#  kill*                             x86_64-linux-gnu-lto-dump-12*
#  krb5-config@                      x86_64-linux-gnu-nm*
#  krb5-config.mit*                  x86_64-linux-gnu-objcopy*
#  last*                             x86_64-linux-gnu-objdump*
#  lastb@                            x86_64-linux-gnu-pkg-config@
#  lastlog*                          x86_64-linux-gnu-pkgconf@
#  lcf*                              x86_64-linux-gnu-ranlib*
#  ld@                               x86_64-linux-gnu-readelf*
#  ld.bfd@                           x86_64-linux-gnu-size*
#  ld.gold@                          x86_64-linux-gnu-strings*
#  ld.so@                            x86_64-linux-gnu-strip*
#  ldd*                              xargs*
#  libnetcfg*                        xml2-config*
#  libpng-config@                    xslt-config*
#  libpng16-config*                  xsubpp*
#  libtoolize*                       xz*
#  libwmf-config*                    xzcat@
#  link*                             xzcmp@
#  linux32@                          xzdiff*
#  linux64@                          xzegrep@
#  ln*                               xzfgrep@
#  locale*                           xzgrep*
#  localedef*                        xzless*
#  logger*                           xzmore*
#  login*                            yes*
#  logname*                          ypdomainname@
#  ls*                               zcat*
#  lsattr*                           zcmp*
#  lsblk*                            zdiff*
#  lscpu*                            zdump*
#  lsfd*                             zegrep*
#  lsipc*                            zfgrep*
#  lsirq*                            zforce*
#  lslocks*                          zgrep*
#  lslogins*                         zipdetails*
#  lsmem*                            zipgrep*
#  lsns*                             zipinfo*
#  lspgpot*                          zless*
#  lto-dump@                         zmore*
#  lto-dump-12@                      znew*

# %%
# The "process_data"-function from the Helical package pre-processes the data. 
# It takes AnnData as an input. 
# More information in our documentation
X_train.var["ensembl_id"] = X_train.var_names
X_test.var["ensembl_id"] = X_test.var_names

train_dataset = geneformer.process_data(X_train, gene_names='ensembl_id')
test_dataset = geneformer.process_data(X_test, gene_names='ensembl_id')
# Out:
# 100%|█████████████████████████████████████████| 660/660 [03:50<00:00,  2.86it/s]
# Map:   0%|          | 0/337776 [00:00<?, ? examples/s]
# 100%|█████████████████████████████████████████| 165/165 [00:58<00:00,  2.83it/s]
# Map:   0%|          | 0/84444 [00:00<?, ? examples/s]

# %%
ref_embeddings = geneformer.get_embeddings(train_dataset)
test_embeddings = geneformer.get_embeddings(test_dataset)
# Out:
#   0%|          | 0/33778 [00:00<?, ?it/s]

# %%
reducer = umap.UMAP(min_dist=0.2, n_components=2, n_epochs=None,n_neighbors=3)
mapper = reducer.fit(ref_embeddings)

plot_df = pd.DataFrame(mapper.embedding_,columns=['px','py'])
labels = X_train.obs['annotation_detailed']
plot_df['Cell Type'] = labels.values


# Create a matplotlib figure and axes
fig, axs = plt.subplots(nrows=1, ncols=2, figsize=(14, 5))

#plt.style.use("dark_background")

sns.scatterplot(data = plot_df,x='px',y='py',sizes=(50,200),ax=axs[0],palette="pastel")
axs[0].set_title('UMAP of Reference Data without labels')

sns.scatterplot(data = plot_df,x='px',y='py',hue='Cell Type',sizes=(50,200),ax=axs[1],palette="pastel")
axs[1].set_title('UMAP of Reference Data with labels')
